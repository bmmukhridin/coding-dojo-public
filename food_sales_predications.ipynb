# %% [markdown]
# <a href="https://colab.research.google.com/github/bmmukhridin/sales-predictions/blob/main/food_sales_predications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 1 - Part 1
#
# ##### Mukhriddin Bakhramov

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Loading Data"

# %%
url ="https://drive.google.com/file/d/1syH81TVrbBsdymLT_jl2JIf6IjPXtSQw/view?usp=sharing"
df = pd.read_csv(url)
df
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="V22kN9L-uLCFP3Z1gEfdig">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>sales_predictions.csv - Google Drive</title><meta property="og:title" content="sales_predictions.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1syH81TVrbBsdymLT_jl2JIf6IjPXtSQw/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                                 try{
# 1                                                   /*
# 2               Copyright The Closure Library Authors.
# 3                  SPDX-License-Identifier: Apache-2.0
# 4                                                   */
# ..                                                 ...
# 111                                  var ck=function(a
# 112                     }catch(e){_._DumpException(e)}
# 113                                    })(this.gbar_);
# 114                                     // Google Inc.
# 115  </script><script id="base-js" async type="text...
#
#                                                    400             500  \
# 0                                                  NaN             NaN
# 1                                                  NaN             NaN
# 2                                                  NaN             NaN
# 3                                                  NaN             NaN
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 111                                                  b  c){_.se.log(46
# 112                                                NaN             NaN
# 113                                                NaN             NaN
# 114                                                NaN             NaN
# 115  wb" nonce="Qe6ELBgBDXqdPL8WxjAcGQ"></script></...             NaN
#
#     700" nonce="V22kN9L-uLCFP3Z1gEfdig"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.tdLy7WXfKaU.L.X.O/am=ABA/d=0/rs=AO0039tni7DjYNo6AIS8TA95G9P3JL0oFg" nonce="V22kN9L-uLCFP3Z1gEfdig"><script nonce="Qe6ELBgBDXqdPL8WxjAcGQ">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 111                                             {att:a
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
#     docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd"      docs-fl:1 docs-l1lc:4  \
# 0                    NaN                     NaN            NaN         NaN
# 1                    NaN                     NaN            NaN         NaN
# 2                    NaN                     NaN            NaN         NaN
# 3                    NaN                     NaN            NaN         NaN
# 4                    NaN                     NaN            NaN         NaN
# ..                   ...                     ...            ...         ...
# 111                max:b                url:c})}  ek=function(a           b
# 112                  NaN                     NaN            NaN         NaN
# 113                  NaN                     NaN            NaN         NaN
# 114                  NaN                     NaN            NaN         NaN
# 115                  NaN                     NaN            NaN         NaN
#
#     docs-l1lm:"LAX" docs-l2lc:2  ... 0.82 0.83 0.84 0.85 1].10 [[null.2  \
# 0               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 1               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 2               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 3               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 4               NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# ..              ...         ...  ...  ...  ...  ...  ...   ...      ...
# 111  c){_.se.log(47      {att:a  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 112             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 113             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 114             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
# 115             NaN         NaN  ...  NaN  NaN  NaN  NaN   NaN      NaN
#
#     null.203 null.204  \
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 111      NaN      NaN
# 112      NaN      NaN
# 113      NaN      NaN
# 114      NaN      NaN
# 115      NaN      NaN
#
#     https://www.gstatic.com/og/_/js/k=og.qtm.en_US.zspU5ZGSCN4.es5.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhba,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTsENZqr_Wh9D_x_8w9_L2NX1US4Pg]]]]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 111                                                NaN
# 112                                                NaN
# 113                                                NaN
# 114                                                NaN
# 115                                                NaN
#
# [116 rows x 799 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Exploratory Visuals

# %% [markdown]
# ## Explanatory Visuals
